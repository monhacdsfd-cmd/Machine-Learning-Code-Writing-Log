# %% [markdown]
# ## 경사 하강법(Gradient Descent)

# %%
dataset = pd.read_csv('LinearRegressionData.csv')
dataset
# Out:
#     hour  score
# 0    0.5     10
# 1    1.2      8
# 2    1.8     14
# 3    2.4     26
# 4    2.6     22
# 5    3.2     30
# 6    3.9     42
# 7    4.4     48
# 8    4.5     38
# 9    5.0     58
# 10   5.3     60
# 11   5.8     72
# 12   6.0     62
# 13   6.1     68
# 14   6.2     72
# 15   6.9     58
# 16   7.2     76
# 17   8.4     86
# 18   8.6     90
# 19  10.0    100

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0) #훈련 80 : 테스트 20 으로 분리

# %% [markdown]
# max_iter : 훈련 세트 반복 횟수(Epoch 횟수)
#
# eta0 : 학습룰(learning late)

# %%
from sklearn.linear_model import SGDRegressor #SGD : Stochastic Gradient Descent 확률적 경사 하강법
#지수 표기법
# 1e-3 = 0.001 (10^-3)
#1e-4 = 0.0001 (10^-4)
#1e+3 = 1000 (10^3)
#1e+4 = 10000 (10^4)

sr = SGDRegressor(max_iter=1000, eta0=1e-4, random_state=0, verbose=1) 
#최대 반복 횟수 1000, 학습률 0.0001, 난수 시드 0
sr.fit(X_train, y_train) #학습
# Out:
# -- Epoch 1
# Norm: 0.27, NNZs: 1, Bias: 0.048869, T: 16, Avg. loss: 1484.241876, Objective: 1484.241877
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 0.47, NNZs: 1, Bias: 0.083896, T: 32, Avg. loss: 1419.741822, Objective: 1419.741828
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 0.64, NNZs: 1, Bias: 0.114272, T: 48, Avg. loss: 1367.983092, Objective: 1367.983108
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 0.79, NNZs: 1, Bias: 0.141552, T: 64, Avg. loss: 1322.870279, Objective: 1322.870304
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 0.94, NNZs: 1, Bias: 0.166772, T: 80, Avg. loss: 1282.550224, Objective: 1282.550260
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 1.07, NNZs: 1, Bias: 0.190476, T: 96, Avg. loss: 1245.587071, Objective: 1245.587122
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 1.20, NNZs: 1, Bias: 0.212877, T: 112, Avg. loss: 1211.227118, Objective: 1211.227183
# ...

# %%
plt.scatter(X_train, y_train, color='blue') #산점도
plt.plot(X_train, sr.predict(X_train), color='green') #선 그래프
plt.title('Hours vs Scores (train data, SGD)') #제목
plt.xlabel('Hours') #x축 이름
plt.ylabel('Scores') #y축 이름
plt.show()

# %%
sr.coef_, sr.intercept_
# Out:
# (array([10.19197471]), array([1.77603038]))

# %%
sr.score(X_test, y_test) #테스트 세트를 통한 모델 평가
# Out:
# 0.9748430825252619

# %%
sr.score(X_train, y_train) #훈련 세트를 통한 모델 평가
# Out:
# 0.9347804758954794
